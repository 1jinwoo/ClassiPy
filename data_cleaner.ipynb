# %%
import numpy as np
import pandas as pd

df = pd.read_csv('search_strings.csv', header=0, sep=',', encoding='latin1')
df
# Out:
#        Unnamed: 0                                         item_title  \
# 0               0  Auto Window Sun Shade Sock Cover Baby Child UV...
# 1               3  EPOXY RESIN 16 oz Kit CRYSTAL CLEAR for Super ...
# 2               5  Crystal Clear Epoxy Resin General Purpose Bar ...
# 3               6  Crystal Clear Epoxy Resin General Purpose Bar ...
# 4               7  * Plastic Casting Resin for Casting in Silicon...
# 5               9  Flex Seal Clear Jumbo Can Liquid Rubber Spray ...
# 6              10   ULTRA CLEAR EPOXY RESIN - Fiberglass, Table T...
# 7              11  Flex Seal Black Jumbo Can Liquid Rubber Spray ...
# 8              13  Crystal Clear Bar Table Top Epoxy Resin Coatin...
# 9              14  Ultra-Low Viscosity Liquid Plastic Urethane Ca...
# 10             17   ULTRA CLEAR EPOXY RESIN - Bar Tops, Table Top...
# 11             18  FiberFix Hi Temp Heat Wrap Fiber Fix 2" x 70" ...
# 12             20  EPOXY RESIN 32 oz Kit CRYSTAL CLEAR for Super ...
# ...
