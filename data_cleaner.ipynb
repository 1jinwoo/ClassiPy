# %%
import numpy as np
import pandas as pd

def read_search_strings(file_path='search_strings.csv'):
    '''
    Reads from csv from file_path
    :return: pandas DataFrame of the csv
    '''
    df = pd.read_csv(file_path, header=0, sep=',', encoding='latin1')
    return df

df = read_search_strings()

# %%
def cleanup_categoryid(df):
    '''
    Assigns new category id starting from 1.
    ** This function modifies df **
    :return: dictionary[key] = categroyId
    '''
    i = 0
    category_dict = dict()
    for j, row in df.iterrows():
        category = row[3]
        if not category in category_dict.keys():
            i += 1
            category_dict[category] = i
            df.at[j, 'categoryId'] = i
        else:
            df.at[j, 'categoryId'] = i
    return category_dict

print(cleanup_categoryid(df))
df[100:200]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-27a8235235fe> in <module>
#      17     return category_dict
#      18
# ---> 19 print(cleanup_categoryid(df))
#      20 df[100:200]
#      21 df
#
# NameError: name 'df' is not defined

# %%
from sklearn.model_selection import train_test_split

def data_split(df, train=0.65, valid=0.15, test=0.20):
    """
    split data into training, validation, and test sets
    :param df: the data set
    :param train: percentage of training data
    :param valid: percentage of validation data
    :param test: percentage of test data
    :return: X_train, X_valid, X_test, Y_train, Y_valid, Y_test
    """

    # instantiate variables
    column_headers = list(df.columns.values)
    X_train = pd.DataFrame()
    X_valid = pd.DataFrame()
    X_test = pd.DataFrame()
    Y_train = pd.DataFrame()
    Y_valid = pd.DataFrame()
    Y_test = pd.DataFrame()
    
    id_num = df['categoryId'].nunique()
    for i in range(1, id_num+1):
        x_category_df = df.loc[df['categoryId'] == i]['item_title']
        y_category_df = df.loc[df['categoryId'] == i]['categoryId']

        x_category_train_valid, x_category_test, y_category_train_valid, y_category_test = \
            train_test_split(x_category_df, y_category_df, test_size=test)
        x_category_train, x_category_valid, y_category_train, y_category_valid = \
            train_test_split(x_category_train_valid, y_category_train_valid, train_size=train/(train+valid))
        X_train = pd.concat([X_train, x_category_train], axis=0)
        X_valid = pd.concat([X_valid, x_category_valid], axis=0)
        X_test = pd.concat([X_test, x_category_test], axis=0)
        Y_train = pd.concat([Y_train, y_category_train], axis=0)
        Y_valid = pd.concat([Y_valid, y_category_valid], axis=0)
        Y_test = pd.concat([Y_test, y_category_test], axis=0)

    return X_train, X_valid, X_test, Y_train, Y_valid, Y_test
data_split(df)
# Out:
# C:\Users\justi\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# (                                                       0
#  154          1 LB Pound Mass Loaded Vinyl 4' x 25' Rolls
#  92     1 x MILLIPUT STANDARD EPOXY PUTTY 2 PART SELF ...
#  97     10x Roll Teflon Plumbing Fitting Thread Seal T...
#  130    12 TUBES Chemlink M1 BLACK Structural Sealant ...
#  56     20 PCS BLACK ELECTRICAL 3M TEMFLEX VINYL TAPE ...
#  121    IPS Weld-On #4SC Plastic Solvent Glue Cement f...
#  37     Norland 61 Optical Adhesive Glue - UV Cure - T...
#  4      * Plastic Casting Resin for Casting in Silicon...
#  123    2 Rolls 26 FT x 1.88" Aluminum Foil Heat Shiel...
#  50     LOCTITE 243 Medium Strength Threadlocker 50ml ...
#  61     3M  1" W x 5' Dual Lock SJ3550 Type 250 VHB Bl...
#  67           Spray Adhesive,Foam and Fabric,20 oz. 3M 24
#  29               WIRE GLUE Electrically Conductive Glue
#  35     Crystal Clear Epoxy Resin General Purpose Bar ...
#  55     Silver Conductive 0.2ML Glue Wire Electrically...
#  2      Crystal Clear Epoxy Resin General Purpose Bar ...
#  90     NEW HOMAX 730657 WELDER PK (2) ALL PURPOSE CON...
#  58     Copper Foil Tape - 2in x 28yds / 25m  -  EMI C...
#  62     1 gal,  CRYSTAL CLEAR, TABLE TOP EPOXY,  HIGH ...
#  167     Low Cost Rear Windshield defroster, Tab, Grid...
#  82     FabriCast 50 Ultra-Low Viscosity Urethane Cast...
#  63     HOT MELT GLUE GUN, ADTECH PRO 200 GLUE GUN,  P...
#  160    CrackWeld® Concrete Floor Repair Kit (2-Pack)...
#  150    30 Foot Long Self Fusing Silicone Rubber Water...
#  103    Food Grade RTV Silicone Sealant Adhesive Red H...
#  105    10mmX 20m 1Roll  EMI Copper Foil Shielding Tap...
#  13      plastic acrylic plexiglass cement glue WELDON...
#  24     Epoxy Resin For Crystal Clear Coating Bar And ...
#  110    2 quarts, TABLE TOP EPOXY RESIN COATING , CRYS...
#  41     IPS Weld-On #16 Plastic Glue Cement for Acryli...
#  ...                                                  ...
#  11086  Women  Sandals  Gladiator Thong Flops T Strap ...
#  11057  Converse All Star Hi Tops Unisex High Tops Cla...
#  11019  Womens Knee High Boots Lace Up Suede Buckles C...
#  11117  Nike T-Lite XI White Leather Womens Athletic  ...
#  11073  NEW Womens T-Strap Thong Gladiator Strappy Bra...
#  10949  Women Riding Boots Slouch Manmade Leather Sexy...
#  10948  Women's Cute Slouch Comfort Casual Flat Heel M...
#  10990  US WOMEN LADIES FLAT LOW WEDGE HEEL ESPADRILLE...
#  11001  Womens Wedding Shoes Peep Toe Platform Heel La...
#  11098  New Women's Flat Wellie Wellington Knee High R...
#  10988  New Women FL23 Tan Black Taupe Brown Gold Stud...
#  11044  Birkenstock Mayari Birko-Flor sandals - Made i...
#  10962  NEW Fashion Strappy Caged Kitten Chunky Heel W...
#  10955  New Authentic Womens Toms Classic Slip On Flat...
#  11105  Alpine Swiss Rose Womens Ballet Flats Pointed ...
#  11081  Women's Summer Open Toe High Block Heels Sanda...
#  11066  Women's High Top Fashion Round Toe Lace Up Wed...
#  11007  UGG Australia Women's Bailey Bow 2 II Boots 10...
#  11020  WOMENS FLAT ZIP UP SLOUCH MID CALF LACE RIDING...
#  11107  Converse Chuck Taylor All Star Classic Colours...
#  11093  New Women Esr Lace Up Combat Military Cuff Fol...
#  11119  Women's Strappy Open Toe Flat Wedge Platform H...
#  11111  Women's Peep Toe Strappy Caged Chucky Heel Ank...
#  11108  Women High Heel Strap Ankle Block Sandals Open...
#  11096  Womens High Heel Lace Up Ankle Boots Ladies Zi...
#  10989  Women's Fashion Strappy Open Toe Platform Wedg...
#  11070  WOMEN'S GLADIATOR ROMAN T-STRAP FLAT THONG FAS...
#  11055  New Women FPS Brown Tan Black Riding Knee High...
#  10957  Womens Boots Knee High Mid Calf Military Flat ...
#  11052  Women's Cute Buckle Zip Almond Toe Stiletto An...
#
#  [7179 rows x 1 columns],
#                                                         0
#  95     Silco 4500 RTV Clear Silicone Sealant Adhesive...
#  66     10mm 100ft BGA High Temperature Heat Resistant...
#  162    Liquid Roof EPDM RV roof coating -5 Gallon -fo...
#  134     Concrete CRACK KIT Epoxy Injection Fix Pools ...
#  140    NEW Power Poxy 2 Part Weld Epoxy Metal Aluminu...
#  104    EPOXY RESIN 2 Gal kit CRYSTAL CLEAR,  Super Gl...
#  68     Tear Mender TG-6H Fabric and Leather Adhesive ...
#  127    Durable Convenient FiberFix Ridiculously Stron...
#  98     Flex Seal Liquid - Liquid Rubber Sealant Coati...
#  109    3 Rolls 19mm x 15m Adhesive Cloth Fabric Tape ...
#  148    48 TUBES Chemlink M1 BLACK Structural Sealant ...
#  107    10mm 100ft BGA High Temperature Heat Resistant...
#  22     50mm 5cm x 30M Kapton Tape Sticky High Tempera...
#  79     Devcon 31345 2 Ton Clear Welder Epoxy Glue Wat...
#  126     JB Weld Industro Cold Weld 2 - 5 Oz. Tubes #8280
#  111    Copper Foil Tape - 1" X 10ft -  EMI Conductive...
#  26     glue adhesive cement  fish tank plexiglass acr...
#  71     Flex Seal Liquid - Liquid Rubber Sealant Coati...
#  132    Copper Foil Tape - 1/8" X 10ft - EMI Conductiv...
#  93     Epoxy Resin Crystal Clear Casting System 4 Coa...
#  0      Auto Window Sun Shade Sock Cover Baby Child UV...
#  156    Make silicone molds and urethane resin parts i...
#  175    Heavy Duty Professional  Caulk Gun, Rotating B...
#  32              Gorilla Duct Tape, 1.88" x 12 yd., Black
#  1      EPOXY RESIN 16 oz Kit CRYSTAL CLEAR for Super ...
#  86     20 Rolls 50 FT Purpose 0.7" Inch Vinyl PVC Bla...
#  151    EPOXY RESIN CRYSTAL CLEAR 16 oz Kit. FOR SUPER...
#  244         12pcs LM8UU 8mm Linear Ball Bearing Bushing
#  192    Fully Licensed Mach3 CNC Software by Artsoft! ...
#  212    10-50V 40A DC Motor Speed Control PWM HHO RC C...
#  ...                                                  ...
#  10895  ZANZEA L-6XL Plus Women Off Shoulder Cocktail ...
#  10802  Low Cut 10 Pairs Ladies Boat Short Cotton New ...
#  10937  Boho Hippie High Waist Wide Leg Long Flared Be...
#  11112  Fashion Women Winter Flat Bottom Shoes Over Th...
#  10969                      WOMENS KNEE HIGH RIDING BOOTS
#  11102  NWT Women's Nike Reax Run 5 Training Shoes Wnt...
#  11047  New Women Pumps Spring Summer Autumn Platform ...
#  11051  NEW Womens Summer Comfort Casual Thong Flat Fl...
#  10986  adidas Climacool 1 Mens Trainers~Originals~UK ...
#  10999  CONVERSE ALL STAR CHUCK TAYLOR CANVAS SHOES LO...
#  10966  Journee Collection Womens Wide and Extra Wide-...
#  11084  Teva Olowahu #6840 Women's Thong Flip Flops Sa...
#  11106  New Authentic TOMS Women's CLASSIC Solid Canva...
#  11008  Converse Lo Top Mens Womens Unisex All Star Lo...
#  11085  Women's Black Ballet Flat Mary Jane Ankle Stra...
#  11113  Ladies Satin Diamante Womens Kitten Mid Platfo...
#  11099                    Crocs Unisex Offroad Sport Clog
#  10952  New Women Gladiator Sandals Shoes Thong Flops ...
#  10996  US New Womens Suede Over The Knee Boots Block ...
#  10985  Women's Sneaker Boots Winter High Top Lace up ...
#  11028  UGG Australia Women's Mini Bailey Bow Boots II...
#  11014  Women's Comfort  Round Toe Flat Low Heel Slouc...
#  11005  Converse All Star Hi Tops Mens Womens Unisex H...
#  11059  New Work Boots Women's Winter Leather Boot Lac...
#  11077  NEW Womens Shoes Combat Boots Ankle Booties Mi...
#  10964  Women's Mid Calf Knee High Round Toe Slouch Co...
#  11049  NEW Women's Fashion Pointy Toe Stiletto High H...
#  11033  PUNK EMO Goth THIGH HIGH Canvas Lace Up Sneake...
#  11110  Women's Combat Round Toe Low Heel  Military La...
#  10972  New Women's Round Toe Lace Up Wedge Heels Sued...
#
#  [1690 rows x 1 columns],
#                                                         0
#  112    4 gals,TABLE TOP EPOXY RESIN, CRYSTAL CLEAR, H...
#  51     LOCTITE 242 Medium Strength Threadlocker 50ml ...
#  48     Polymat 797 High-Temp Adhesive Automotive Vehi...
#  138    6 TUBES Chemlink M1 BLACK Structural Sealant -...
#  11     FiberFix Hi Temp Heat Wrap Fiber Fix 2" x 70" ...
#  161    1 Inch x 72 yds - High Temperature Polyester G...
#  171    Milwaukee 2441-20 M12 12-Volt 10-Ounce Caulk A...
#  172    25mm x 300cm Silicone Rubber Waterproof Adhesi...
#  10      ULTRA CLEAR EPOXY RESIN - Bar Tops, Table Top...
#  159    2rolls Heat resistant tapes sublimation Press ...
#  115    Flex Shot Black 8-oz. Thick Rubber Adhesive Se...
#  88     Crystal Clear Bar Table Top Epoxy Resin Coatin...
#  106    High-Temperature Rocksett, Adhesive Ceramic Ce...
#  40     crystal clear epoxy resin art resin flow art e...
#  164    0.5ML Silver Conductive Wire Glue Adhesive Pas...
#  9      Ultra-Low Viscosity Liquid Plastic Urethane Ca...
#  169    15 Rolls 60 FT General Purpose Masking Tape 0....
#  44     20mm 2cm X 30M 100ft Kapton Tape High Temperat...
#  94     High temp Silco 3 oz Food Safe RTV Silicone Se...
#  38     NEW J B WELD 8280 INDUSTRO LARGE 10OZ WELD ADH...
#  153    3M 4" x 8"   VHB Double Sided Foam Adhesive Ta...
#  133    4 TUBES Chemlink M1 BLACK Structural Sealant -...
#  31     Polymat 797 Hi Temp Spray Adhesive 20oz Can hi...
#  113    DAP Weldwood Contact Cement Top & Trim HHR Sol...
#  158    Norland 61 Optical Adhesive - UV Cure - NOA61-...
#  116    Devcon 35345 Clear 2 Ton High Strength Epoxy G...
#  7      Flex Seal Black Jumbo Can Liquid Rubber Spray ...
#  18     Black Rubber Silicone Repair Waterproof Bondin...
#  149    ProTapes Pro Gaff BLACK GAFFERS TAPE 2" x 55 y...
#  3      Crystal Clear Epoxy Resin General Purpose Bar ...
#  ...                                                  ...
#  11013  Women High Top Wedge Heel Sneakers Platform La...
#  10973  New Womens Flat Wellies Mid Calf Rubber Rain &...
#  11069                     adidas SUPERSTAR MT W Women's
#  11079  Toms Women's Classics Slip On Black on Black. ...
#  11012   New Women's Nike Benassi JDI Slides Sandals F...
#  11004  Medical Nursing Nurse Womens Comfortable Light...
#  11104  Fashion Womens Lady Slipper Slip On Sliders Fl...
#  11009  New Womens JM18 Red Zipper Tan Studded Riding ...
#  10961  SALE BIRKENSTOCK Arizona or Soft Footbed Arizo...
#  11029  New Women DA14 Stretchy Lace Up Over the Knee ...
#  10967  2018 Fashion New Women's Sneakers Sport Breath...
#  11031          Women's Pretty Glitters Flat Ballet Shoes
#  11053  Women's Cute Open Toe Ankle Strap Chunky Heels...
#  11091  Women's Lace High Top Fashion Sneaker Hidden W...
#  10976  WOMENS NEW FLAT LOW WEDGE HEELS ESPADRILLES SU...
#  11036  Journee Collection Womens Wide and Extra Wide ...
#  11018  Women's Boots Ankle Flat Heel Xoford Lace Up R...
#  11120  Women's High Top Lace Up Wedge Fashion Sneaker...
#  11065  Women's Open Toe Strappy Gladiator Heel Low We...
#  10951  NEW  Women's Zipper Military Low Flat Heel  Bu...
#  10960  Women's Fashion Low Flat Heel Mid-Calf  Knee H...
#  11068  Birkenstock Arizona EVA Unisex Shoes Slides Sa...
#  10946  Men's Sperry Top-Sider Original A/O 2-Eye Boat...
#  11115  New Women BM77 Brown Western Knee High Riding ...
#  11048  New Women's Fashion Dress  Low Heel Zipper Mid...
#  10974  Women Sequin Glitter Sneakers Tennis Lightweig...
#  11017  New Women Gladiator Sandals Shoes Thong Flops ...
#  11038  Women's Cute Causal  Round Toe Low  Wedge Plat...
#  10979  Alpine Swiss Sabine Womens Suede Shearling Moc...
#  11061  CONVERSE Chuck Taylor All Star Low Top Shoes U...
#
#  [2253 rows x 1 columns],
#            0
#  154     1.0
#  92      1.0
#  97      1.0
#  130     1.0
#  56      1.0
#  121     1.0
#  37      1.0
#  4       1.0
#  123     1.0
#  50      1.0
#  61      1.0
#  67      1.0
#  29      1.0
#  35      1.0
#  55      1.0
#  2       1.0
#  90      1.0
#  58      1.0
#  62      1.0
#  167     1.0
#  82      1.0
#  63      1.0
#  160     1.0
#  150     1.0
#  103     1.0
#  105     1.0
#  13      1.0
#  24      1.0
#  110     1.0
#  41      1.0
#  ...     ...
#  11086  63.0
#  11057  63.0
#  11019  63.0
#  11117  63.0
#  11073  63.0
#  10949  63.0
#  10948  63.0
#  10990  63.0
#  11001  63.0
#  11098  63.0
#  10988  63.0
#  11044  63.0
#  10962  63.0
#  10955  63.0
#  11105  63.0
#  11081  63.0
#  11066  63.0
#  11007  63.0
#  11020  63.0
#  11107  63.0
#  11093  63.0
#  11119  63.0
#  11111  63.0
#  11108  63.0
#  11096  63.0
#  10989  63.0
#  11070  63.0
#  11055  63.0
#  10957  63.0
#  11052  63.0
#
#  [7179 rows x 1 columns],
#            0
#  95      1.0
#  66      1.0
#  162     1.0
#  134     1.0
#  140     1.0
#  104     1.0
#  68      1.0
#  127     1.0
#  98      1.0
#  109     1.0
#  148     1.0
#  107     1.0
#  22      1.0
#  79      1.0
#  126     1.0
#  111     1.0
#  26      1.0
#  71      1.0
#  132     1.0
#  93      1.0
#  0       1.0
#  156     1.0
#  175     1.0
#  32      1.0
#  1       1.0
#  86      1.0
#  151     1.0
#  244     2.0
#  192     2.0
#  212     2.0
#  ...     ...
#  10895  62.0
#  10802  62.0
#  10937  62.0
#  11112  63.0
#  10969  63.0
#  11102  63.0
#  11047  63.0
#  11051  63.0
#  10986  63.0
#  10999  63.0
#  10966  63.0
#  11084  63.0
#  11106  63.0
#  11008  63.0
#  11085  63.0
#  11113  63.0
#  11099  63.0
#  10952  63.0
#  10996  63.0
#  10985  63.0
#  11028  63.0
#  11014  63.0
#  11005  63.0
#  11059  63.0
#  11077  63.0
#  10964  63.0
#  11049  63.0
#  11033  63.0
#  11110  63.0
#  10972  63.0
#
#  [1690 rows x 1 columns],
#            0
#  112     1.0
#  51      1.0
#  48      1.0
#  138     1.0
#  11      1.0
#  161     1.0
#  171     1.0
#  172     1.0
#  10      1.0
#  159     1.0
#  115     1.0
#  88      1.0
#  106     1.0
#  40      1.0
#  164     1.0
#  9       1.0
#  169     1.0
#  44      1.0
#  94      1.0
#  38      1.0
#  153     1.0
#  133     1.0
#  31      1.0
#  113     1.0
#  158     1.0
#  116     1.0
#  7       1.0
#  18      1.0
#  149     1.0
#  3       1.0
#  ...     ...
#  11013  63.0
#  10973  63.0
#  11069  63.0
#  11079  63.0
#  11012  63.0
#  11004  63.0
#  11104  63.0
#  11009  63.0
#  10961  63.0
#  11029  63.0
#  10967  63.0
#  11031  63.0
#  11053  63.0
#  11091  63.0
#  10976  63.0
#  11036  63.0
#  11018  63.0
#  11120  63.0
#  11065  63.0
#  10951  63.0
#  10960  63.0
#  11068  63.0
#  10946  63.0
#  11115  63.0
#  11048  63.0
#  10974  63.0
#  11017  63.0
#  11038  63.0
#  10979  63.0
#  11061  63.0
#
#  [2253 rows x 1 columns])
